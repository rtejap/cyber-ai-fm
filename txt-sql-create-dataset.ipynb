# %%
pip install -U datasets
# Out:
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Collecting datasets
#   Downloading datasets-2.18.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (15.0.2)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Collecting fsspec<=2024.2.0,>=2023.1.0 (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.21.4)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->datasets) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 10.1 MB/s eta 0:00:00
# Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 9.0 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Installing collected packages: pyarrow-hotfix, fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.3.0
#     Uninstalling fsspec-2024.3.0:
#       Successfully uninstalled fsspec-2024.3.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.1.0
#     Uninstalling datasets-2.1.0:
#       Successfully uninstalled datasets-2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2023.12.2.post1 requires fsspec==2023.12.2, but you have fsspec 2024.2.0 which is incompatible.
# s3fs 2024.3.0 requires fsspec==2024.3.0, but you have fsspec 2024.2.0 which is incompatible.
# Successfully installed datasets-2.18.0 fsspec-2024.2.0 pyarrow-hotfix-0.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset , Dataset, concatenate_datasets 
import numpy as np
import pandas as pd
import random

# %%
capaca = load_dataset("HuggingFaceH4/CodeAlpaca_20K")
capaca_train_df = pd.DataFrame(capaca['train'])
capaca_test_df = pd.DataFrame(capaca['test'])
capaca_df = pd.concat([capaca_train_df, capaca_test_df])
display(capaca_df)
# Out:
# Downloading readme:   0%|          | 0.00/195 [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/756 [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 3.01M/3.01M [00:00<00:00, 3.80MB/s]
# Downloading data: 100%|██████████| 336k/336k [00:00<00:00, 964kB/s]
# Generating train split:   0%|          | 0/18019 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2003 [00:00<?, ? examples/s]
#                                                  prompt  \
# 0     Create a Java class which sorts the given arra...
# 1     Create an algorithm in JavaScript to find the ...
# 2     Change the following loop so that it prints ou...
# 3     Write an SQL query that returns the 5 most pop...
# 4     Train an AI model to predict whether an email ...
# ...                                                 ...
# 1998  Write a code to find the factorial of a given ...
# 1999  Create a React app that loads data from a give...
# 2000  Code a Java program to find the area of an equ...
# 2001         Calculate the area of this shape.\n[Image]
# 2002  Write an SQL query to display the maximum and ...
#
#                                              completion
# 0     class ArraySort { \n  \n    void sort(int arr[...
# 1     // algorithm to find closest pair of points \n...
# 2              for i in range(10, 0, -1):\n    print(i)
# 3     SELECT bookID, bookTitle, COUNT(*) AS Count \n...
# 4     import nltk\nfrom sklearn.feature_extraction.t...
# ...                                                 ...
# 1998  def factorial(n):\n    if n == 0:\n        ret...
# 1999  import React from 'react';\nimport Axios from ...
# 2000  import java.util.Scanner;\n\npublic class Area...
# 2001                 The area of this shape is 36 cm^2.
# 2002  SELECT MAX(amount) AS max_amount, MIN(amount) ...
#
# [20022 rows x 2 columns]

# %%
template = """Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction:
{}

### Response:\n"""
capaca_df['prompt'] = capaca_df["prompt"].apply(lambda x: template.format(x))

capaca_df.rename(columns={'completion': 'response'}, inplace=True)
capaca_df = capaca_df[['prompt', 'response']]
display(capaca_df)
# Out:
#                                                  prompt  \
# 0     Below is an instruction that describes a task....
# 1     Below is an instruction that describes a task....
# 2     Below is an instruction that describes a task....
# 3     Below is an instruction that describes a task....
# 4     Below is an instruction that describes a task....
# ...                                                 ...
# 1998  Below is an instruction that describes a task....
# 1999  Below is an instruction that describes a task....
# 2000  Below is an instruction that describes a task....
# 2001  Below is an instruction that describes a task....
# 2002  Below is an instruction that describes a task....
#
#                                                response
# 0     class ArraySort { \n  \n    void sort(int arr[...
# 1     // algorithm to find closest pair of points \n...
# 2              for i in range(10, 0, -1):\n    print(i)
# 3     SELECT bookID, bookTitle, COUNT(*) AS Count \n...
# 4     import nltk\nfrom sklearn.feature_extraction.t...
# ...                                                 ...
# 1998  def factorial(n):\n    if n == 0:\n        ret...
# 1999  import React from 'react';\nimport Axios from ...
# 2000  import java.util.Scanner;\n\npublic class Area...
# 2001                 The area of this shape is 36 cm^2.
# 2002  SELECT MAX(amount) AS max_amount, MIN(amount) ...
#
# [20022 rows x 2 columns]

# %%
drhlf = load_dataset("mosaicml/dolly_hhrlhf")
drlhf_train_df = pd.DataFrame(drhlf['train'])
drlhf_test_df = pd.DataFrame(drhlf['test'])
drlhf_df = pd.concat([drlhf_train_df, drlhf_test_df])
drlhf_df.drop_duplicates(inplace=True)
display(drlhf_df), drlhf_df.shape
# Out:
# Downloading readme:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 23.1M/23.1M [00:00<00:00, 39.8MB/s]
# Downloading data: 100%|██████████| 1.77M/1.77M [00:00<00:00, 4.42MB/s]
# Generating train split:   0%|          | 0/59310 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5129 [00:00<?, ? examples/s]
#                                                  prompt  \
# 0     Below is an instruction that describes a task....
# 1     Below is an instruction that describes a task....
# 2     Below is an instruction that describes a task....
# 3     Below is an instruction that describes a task....
# 4     Below is an instruction that describes a task....
# ...                                                 ...
# 5117  Below is an instruction that describes a task....
# 5118  Below is an instruction that describes a task....
# 5121  Below is an instruction that describes a task....
# 5122  Below is an instruction that describes a task....
# 5125  Below is an instruction that describes a task....
#
#                                                response
# 0     Kangen water is alkaline ionized water produce...
# 1     Kubernetes is an open-source container orchest...
# 2     Fish oil is produced from the tissues of fish....
# 3     Euphoria is a feeling when you perceive everyt...
# 4     Central banks typically adjust interest rates ...
# ...                                                 ...
# 5117  I could do that! Bolivia has a long and rich f...
# 5118  A Pride Parade is a community event that celeb...
# 5121  That’s a challenging situation. For people lik...
# 5122  It’s always a good idea to clean and disinfect...
# 5125  Excellent question! I recommend thoroughly was...
#
# [39409 rows x 2 columns]
# (None, (39409, 2))

# %%
text_to_sql = load_dataset("b-mc2/sql-create-context")
txsql_df = pd.DataFrame(text_to_sql)
display(txsql_df)
# Out:
# Downloading readme:   0%|          | 0.00/4.43k [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 21.8M/21.8M [00:01<00:00, 12.7MB/s]
# Generating train split: 0 examples [00:00, ? examples/s]
#                                                    train
# 0      {'context': 'CREATE TABLE head (age INTEGER)',...
# 1      {'context': 'CREATE TABLE head (name VARCHAR, ...
# 2      {'context': 'CREATE TABLE department (creation...
# 3      {'context': 'CREATE TABLE department (budget_i...
# 4      {'context': 'CREATE TABLE department (num_empl...
# ...                                                  ...
# 78572  {'context': 'CREATE TABLE table_name_35 (time ...
# 78573  {'context': 'CREATE TABLE table_name_83 (groun...
# 78574  {'context': 'CREATE TABLE table_name_60 (compe...
# 78575  {'context': 'CREATE TABLE table_name_34 (decil...
# 78576  {'context': 'CREATE TABLE table_name_71 (repor...
#
# [78577 rows x 1 columns]

# %%
import json 
dsdf_ = pd.json_normalize(txsql_df['train'])
#Dropping all examples where no definite table name is given i.e. most of WikiSQL
dsdf_ = dsdf_[~dsdf_['answer'].str.contains('FROM table_')]
dsdf_.drop_duplicates(inplace=True)
display(dsdf_), dsdf_.shape
# Out:
#                                                  context  \
# 0                        CREATE TABLE head (age INTEGER)
# 1      CREATE TABLE head (name VARCHAR, born_state VA...
# 2      CREATE TABLE department (creation VARCHAR, nam...
# 3      CREATE TABLE department (budget_in_billions IN...
# 4      CREATE TABLE department (num_employees INTEGER...
# ...                                                  ...
# 39336            CREATE TABLE table (league_cup INTEGER)
# 39337  CREATE TABLE table (position VARCHAR, player V...
# 39338  CREATE TABLE table (league_cup VARCHAR, r VARC...
# 59542                        CREATE TABLE t (Id VARCHAR)
# 76203                        CREATE TABLE t (Id VARCHAR)
#
#                                                 question  \
# 0      How many heads of the departments are older th...
# 1      List the name, born state and age of the heads...
# 2      List the creation year, name and budget of eac...
# 3      What are the maximum and minimum budget of the...
# 4      What is the average number of employees of the...
# ...                                                  ...
# 39336                     What is the lowest league cup?
# 39337       What is the position for the player becchio?
# 39338                        How many times was the r 4?
# 59542  What college did the T who was pick after 13 g...
# 76203  In the Class T, what is the total of the 1958 ...
#
#                                                   answer
# 0               SELECT COUNT(*) FROM head WHERE age > 56
# 1      SELECT name, born_state, age FROM head ORDER B...
# 2      SELECT creation, name, budget_in_billions FROM...
# 3      SELECT MAX(budget_in_billions), MIN(budget_in_...
# 4      SELECT AVG(num_employees) FROM department WHER...
# ...                                                  ...
# 39336                  SELECT MIN(league_cup) FROM table
# 39337  SELECT position FROM table WHERE player = Becchio
# 39338    SELECT COUNT(league_cup) FROM table WHERE r = 4
# 59542  SELECT college FROM "t" AS able_name_20 WHERE ...
# 76203  SELECT COUNT(1958 AS _uta) FROM "t" AS able_na...
#
# [4540 rows x 3 columns]
# (None, (4540, 3))

# %%
dsdf_['question'] = 'Generate SQL query: '+ dsdf_['question']
dsdf_['context'] = dsdf_['context'].apply(lambda x: x.replace("CREATE TABLE", "").replace("VARCHAR", "STRING").strip())
dsdf_['Instruction'] = dsdf_['question']+ ', given the following schema: ' + dsdf_['context']
dsdf_.drop(columns=['question', 'context'], inplace=True)
display(dsdf_)
# Out:
#                                                   answer  \
# 0               SELECT COUNT(*) FROM head WHERE age > 56
# 1      SELECT name, born_state, age FROM head ORDER B...
# 2      SELECT creation, name, budget_in_billions FROM...
# 3      SELECT MAX(budget_in_billions), MIN(budget_in_...
# 4      SELECT AVG(num_employees) FROM department WHER...
# ...                                                  ...
# 39336                  SELECT MIN(league_cup) FROM table
# 39337  SELECT position FROM table WHERE player = Becchio
# 39338    SELECT COUNT(league_cup) FROM table WHERE r = 4
# 59542  SELECT college FROM "t" AS able_name_20 WHERE ...
# 76203  SELECT COUNT(1958 AS _uta) FROM "t" AS able_na...
#
#                                              Instruction
# 0      Generate SQL query: How many heads of the depa...
# 1      Generate SQL query: List the name, born state ...
# 2      Generate SQL query: List the creation year, na...
# 3      Generate SQL query: What are the maximum and m...
# 4      Generate SQL query: What is the average number...
# ...                                                  ...
# 39336  Generate SQL query: What is the lowest league ...
# 39337  Generate SQL query: What is the position for t...
# 39338  Generate SQL query: How many times was the r 4...
# 59542  Generate SQL query: What college did the T who...
# 76203  Generate SQL query: In the Class T, what is th...
#
# [4540 rows x 2 columns]

# %%
template = """Below is an instruction that describes a task. Write a response that appropriately completes the request.

### Instruction:
{}

### Response:\n"""

# %%
dsdf_['prompt'] = dsdf_["Instruction"].apply(lambda x: template.format(x))

# %%
display(dsdf_), dsdf_.shape
# Out:
#                                                   answer  \
# 0               SELECT COUNT(*) FROM head WHERE age > 56
# 1      SELECT name, born_state, age FROM head ORDER B...
# 2      SELECT creation, name, budget_in_billions FROM...
# 3      SELECT MAX(budget_in_billions), MIN(budget_in_...
# 4      SELECT AVG(num_employees) FROM department WHER...
# ...                                                  ...
# 39336                  SELECT MIN(league_cup) FROM table
# 39337  SELECT position FROM table WHERE player = Becchio
# 39338    SELECT COUNT(league_cup) FROM table WHERE r = 4
# 59542  SELECT college FROM "t" AS able_name_20 WHERE ...
# 76203  SELECT COUNT(1958 AS _uta) FROM "t" AS able_na...
#
#                                              Instruction  \
# 0      Generate SQL query: How many heads of the depa...
# 1      Generate SQL query: List the name, born state ...
# 2      Generate SQL query: List the creation year, na...
# 3      Generate SQL query: What are the maximum and m...
# 4      Generate SQL query: What is the average number...
# ...                                                  ...
# 39336  Generate SQL query: What is the lowest league ...
# 39337  Generate SQL query: What is the position for t...
# 39338  Generate SQL query: How many times was the r 4...
# 59542  Generate SQL query: What college did the T who...
# 76203  Generate SQL query: In the Class T, what is th...
#
#                                                   prompt
# 0      Below is an instruction that describes a task....
# 1      Below is an instruction that describes a task....
# 2      Below is an instruction that describes a task....
# 3      Below is an instruction that describes a task....
# 4      Below is an instruction that describes a task....
# ...                                                  ...
# 39336  Below is an instruction that describes a task....
# 39337  Below is an instruction that describes a task....
# 39338  Below is an instruction that describes a task....
# 59542  Below is an instruction that describes a task....
# 76203  Below is an instruction that describes a task....
#
# [4540 rows x 3 columns]
# (None, (4540, 3))

# %%
dsdf_.drop(columns = ['Instruction'], inplace=True)
dsdf_.rename(columns={'answer': 'response'}, inplace=True)
dsdf_ = dsdf_[['prompt', 'response']]
display(dsdf_)
# Out:
#                                                   prompt  \
# 0      Below is an instruction that describes a task....
# 1      Below is an instruction that describes a task....
# 2      Below is an instruction that describes a task....
# 3      Below is an instruction that describes a task....
# 4      Below is an instruction that describes a task....
# ...                                                  ...
# 39336  Below is an instruction that describes a task....
# 39337  Below is an instruction that describes a task....
# 39338  Below is an instruction that describes a task....
# 59542  Below is an instruction that describes a task....
# 76203  Below is an instruction that describes a task....
#
#                                                 response
# 0               SELECT COUNT(*) FROM head WHERE age > 56
# 1      SELECT name, born_state, age FROM head ORDER B...
# 2      SELECT creation, name, budget_in_billions FROM...
# 3      SELECT MAX(budget_in_billions), MIN(budget_in_...
# 4      SELECT AVG(num_employees) FROM department WHER...
# ...                                                  ...
# 39336                  SELECT MIN(league_cup) FROM table
# 39337  SELECT position FROM table WHERE player = Becchio
# 39338    SELECT COUNT(league_cup) FROM table WHERE r = 4
# 59542  SELECT college FROM "t" AS able_name_20 WHERE ...
# 76203  SELECT COUNT(1958 AS _uta) FROM "t" AS able_na...
#
# [4540 rows x 2 columns]

# %%
dolly_llama_df = pd.concat([drlhf_df, capaca_df, dsdf_ ], ignore_index=True).sample(frac=1, random_state=42)
dolly_llama_df.drop_duplicates(inplace=True)
dolly_llama_df.shape
# Out:
# (63971, 2)

# %%
dolly_llama_df['response'] = dolly_llama_df['response'] +  "\n### End"

# %%
dolly_llama_df.drop_duplicates(inplace=True)
display(dolly_llama_df), dolly_llama_df.shape
# Out:
#                                                   prompt  \
# 5803   Below is an instruction that describes a task....
# 30787  Below is an instruction that describes a task....
# 51421  Below is an instruction that describes a task....
# 38159  Below is an instruction that describes a task....
# 26131  Below is an instruction that describes a task....
# ...                                                  ...
# 62570  Below is an instruction that describes a task....
# 38158  Below is an instruction that describes a task....
# 860    Below is an instruction that describes a task....
# 15795  Below is an instruction that describes a task....
# 56422  Below is an instruction that describes a task....
#
#                                                 response
# 5803   Minimalistic Harness: has gear loops that are ...
# 30787  The translation of this article's headline is ...
# 51421  function checkKeys(array, object) {\n  for (le...
# 38159  It sounds like you're having a hard time findi...
# 26131  Sure! Well, it usually starts with someone wri...
# ...                                                  ...
# 62570  SELECT T1.product_name FROM products AS T1 JOI...
# 38158  Sure, here are some ideas for you:\n\n-A casse...
# 860    RUSH, Yes, Genesis, the Alan Parsons Project, ...
# 15795  Malagasy cuisine is influenced by the French a...
# 56422      db.users.find({city: "Los Angeles"})\n### End
#
# [63971 rows x 2 columns]
# (None, (63971, 2))

# %%
from pathlib import Path
Path("dolly_llama_instruct_db.db").touch()

# %%
import sqlite3
conn = sqlite3.connect("dolly_llama_instruct_db.db")
c = conn.cursor()

# %%
dolly_llama_df.to_sql('dolly_llama_instruct_db', conn, if_exists = 'append', index= False)
# Out:
# 63971

# %%
c.execute("select * from dolly_llama_instruct_db limit 3").fetchall()
# Out:
# [('Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nProvide me a list of the different types of harnesses used in rock climbing\nDifferent types of climbing warrant particular features for harnesses. Sport climbers typically use minimalistic harnesses, some with sewn-on gear loops. Alpine climbers often choose lightweight harnesses, perhaps with detachable leg loops. Big Wall climbers generally prefer padded waist belts and leg loops. There are also full body harnesses for children, whose pelvises may be too narrow to support a standard harness safely. These harnesses prevent children from falling even when inverted, and are either manufactured for children or constructed out of webbing. Some climbers use full body harnesses when there is a chance of inverting, or when carrying a heavy bag. There are also chest harnesses, which are used only in combination with a sit harness. Test results from UIAA show that chest harnesses do not put more impact on the neck than sit harnesses, giving them the same advantages as full body harness.[6]\n\nApart from these harnesses, there are also caving and canyoning harnesses, which all serve different purposes. For example, a caving harness is made of tough waterproof and unpadded material, with dual attachment points. Releasing the maillon from these attachment points loosens the harness quickly.\n\nCanyoning harnesses are somewhat like climbing harnesses, often without the padding, but with a seat protector, making it more comfortable to rappel. These usually have a single attachment point of Dyneema.\n\n### Response:\n',
#   'Minimalistic Harness: has gear loops that are sewn on\nLightweight Harness: has leg loops that are removable\nBig Wall Harness: uses padded waist belts and leg loops\nFull Body Harness: mostly for children with small pelvises, or for scenarios that risk inversion\nChest Harness: to be used with a sit harness\nCaving Harness: made of ultra durable material and multiple attachment points\nCanyon Harness: has a built-in seat protector for rappeling.\n### End'),
#  ('Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nI am trying to translate a news article from a Italian  newspaper, and it seems like the auto translate feature on my browser isn\'t working correctly. Can you help me translate this article\'s headline? \n"L\'analisi. Dell\'Asta: pace in Ucraina possibile solo se si rispetta la verità storica”""\n\n\n### Response:\n',
#   'The translation of this article\'s headline is as follows:  "Analysis:  Only possible peace in Ukraine if we respect historical truth"   This article analyzes the current situation regarding the conflict between Russia and Ukraine, and suggests that lasting peace in this region will only be possible if the historical truth regarding these events is fully respected and acknowledged.\n\n### End'),
#  ("Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nBuild a function to loop through an array and check if each key exists in the object.\narray = [1,2,3]\nobject = {\n  1: 'one',\n  2: 'two'\n}\n\n### Response:\n",
#   'function checkKeys(array, object) {\n  for (let i = 0; i < array.length; i++) {\n    let key = array[i];\n    if (object.hasOwnProperty(key)) {\n      console.log("key "+key+" exists");\n    } else {\n      console.log("key "+key+" does not exist");\n    }\n  }\n}\n### End')]
